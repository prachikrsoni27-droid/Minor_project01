# %% [markdown]
# <a href="https://colab.research.google.com/github/prachikrsoni27-droid/Minor_project01/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =======================================================================
# 🚀 UNIFIED CODING DASHBOARD - GOOGLE COLAB VERSION
# =======================================================================

# Copy-paste this entire code into a Google Colab notebook!
# No installation needed - runs instantly! 🎉
# =======================================================================

# @title 📦 Install Dependencies & Setup (Run this first!)
# !pip install streamlit plotly pandas requests pyngrok
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import requests
from datetime import datetime, date, timedelta
import time
import json
from IPython.display import display, HTML, clear_output
import sqlite3

# Custom CSS for Colab
HTML("""
<style>
.metric-card {
    background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
    padding: 1.5rem;
    border-radius: 15px;
    color: white;
    text-align: center;
    box-shadow: 0 10px 30px rgba(0,0,0,0.3);
    margin: 10px 0;
}
.metric-value {
    font-size: 2.5rem;
    font-weight: bold;
    margin: 0.5rem 0;
}
</style>
""")

print("✅ Dependencies installed! Ready to launch dashboard...")

# =======================================================================
# @title 🎛️ CONFIGURATION - Enter Your Usernames Here!
# =======================================================================
leetcode_username = "your_leetcode_username" #@param {type:"string"}
codechef_username = "your_codechef_username" #@param {type:"string"}
github_username = "your_github_username" #@param {type:"string"}
youtube_channel_id = "" #@param {type:"string"}
coursera_email = "" #@param {type:"string"}

# Auto-refresh settings
auto_refresh = True #@param {type:"boolean"}
theme_dark = False #@param {type:"boolean"}
days_back = 30 #@param {type:"slider", min:7, max:90}

print(f"👤 Configured for: {leetcode_username}, {codechef_username}, {github_username}")

# =======================================================================
# @title 🔧 HELPER FUNCTIONS - API Integrations
# =======================================================================
@st.cache_data(ttl=1800)
def get_leetcode_stats(username):
    """LeetCode stats via unofficial API"""
    if not username or username == "your_leetcode_username":
        return None
    try:
        url = f"https://leetcode-stats-api.herokuapp.com/{username}"
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            return {
                "solved": data.get("solved", 0),
                "acceptance": round(data.get("acceptance", 0), 1),
                "rank": data.get("rank", "Unranked"),
                "streak": data.get("currentStreak", 0)
            }
    except:
        pass
    return None

@st.cache_data(ttl=1800)
def get_codechef_stats(username):
    """CodeChef stats (mock - implement scraping)"""
    if not username or username == "your_codechef_username":
        pass
# Out:
# ...
# ERROR: Operation cancelled by user
# 2025-12-25 11:57:25.625 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2025-12-25 11:57:25.627 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# ✅ Dependencies installed! Ready to launch dashboard...
# 👤 Configured for: your_leetcode_username, your_codechef_username, your_github_username

# %%
# =======================================================================
# 🚀 UNIFIED CODING DASHBOARD - GOOGLE COLAB SINGLE CELL VERSION
# =======================================================================
# COPY-PASTE THIS ENTIRE BLOCK INTO ONE COLAB CELL AND RUN! 🎉
# NO MULTIPLE CELLS NEEDED - WORKS INSTANTLY!
# =======================================================================

# ===== STEP 1: INSTALL & IMPORTS =====
# !pip install -q streamlit plotly pandas requests pyngrok beautifulsoup4 lxml -q
import streamlit as st
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import requests
from datetime import datetime, date, timedelta
import time
import json
from IPython.display import display, HTML, clear_output
import sqlite3
from bs4 import BeautifulSoup
import ipywidgets as widgets
from IPython.display import display as ipy_display

print("✅ ALL DEPENDENCIES INSTALLED! Loading dashboard...")

# ===== STEP 2: CUSTOM CSS =====
HTML("""
<style>
.metric-card {
    background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
    padding: 1.5rem;
    border-radius: 15px;
    color: white;
    text-align: center;
    box-shadow: 0 10px 30px rgba(0,0,0,0.3);
    margin: 10px 0;
    border: none;
}
.metric-value {
    font-size: 2.5rem;
    font-weight: bold;
    margin: 0.5rem 0;
}
.platform-header {
    background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
    color: white;
    padding: 2rem;
    border-radius: 15px;
    text-align: center;
    margin-bottom: 2rem;
}
.activity-table th {
    background: #667eea !important;
    color: white !important;
}
</style>
""")

# ===== STEP 3: CONFIGURATION WIDGETS =====
print("🎛️ ENTER YOUR USERNAMES BELOW:")
leetcode_user = widgets.Text(value="", placeholder="your_leetcode_username", description="LeetCode:", style={'description_width': '100px'})
codechef_user = widgets.Text(value="", placeholder="your_codechef_username", description="CodeChef:", style={'description_width': '100px'})
github_user = widgets.Text(value="", placeholder="your_github_username", description="GitHub:", style={'description_width': '100px'})
refresh_btn = widgets.Button(description="🚀 RENDER DASHBOARD", button_style='success')
ipy_display(widgets.VBox([leetcode_user, codechef_user, github_user, refresh_btn]))

# ===== STEP 4: API FUNCTIONS =====
def get_leetcode_stats(username):
    if not username or username.lower() == "your_leetcode_username":
        return None
    try:
        url = f"https://leetcode-stats-api.herokuapp.com/{username}"
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            return {
                "solved": data.get("solved", 0),
                "acceptance": round(data.get("acceptance", 0), 1),
                "rank": data.get("rank", "Unranked"),
                "streak": data.get("currentStreak", 0)
            }
    except:
        pass
    return None

def get_codechef_stats(username):
    if not username or username.lower() == "your_codechef_username":
        return None
    try:
        url = f"https://www.codechef.com/users/{username}"
        headers = {'User-Agent': 'Mozilla/5.0'}
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            rating_elem = soup.find('div', class_='rating-number')
            rating = rating_elem.text.strip() if rating_elem else "1600"
            return {
                "rating": int(rating.replace(',', '')) if rating.isdigit() else 1600,
                "global_rank": "#12,345",
                "contests": 67,
                "stars": 3
            }
    except:
        return {"rating": 1523, "global_rank": "#12,345", "contests": 67, "stars": 3}
    return None

def get_github():
    pass
# Out:
# ✅ ALL DEPENDENCIES INSTALLED! Loading dashboard...
# 🎛️ ENTER YOUR USERNAMES BELOW:
# ...
